# %% [markdown]
# Set Dependencies, Load CSV files, Combine CSV Files

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load 
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
school_data_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39170 entries, 0 to 39169
# Data columns (total 11 columns):
# Student ID       39170 non-null int64
# student_name     39170 non-null object
# gender           39170 non-null object
# grade            39170 non-null object
# school_name      39170 non-null object
# reading_score    39170 non-null int64
# math_score       39170 non-null int64
# School ID        39170 non-null int64
# type             39170 non-null object
# size             39170 non-null int64
# budget           39170 non-null int64
# dtypes: int64(6), object(5)
# memory usage: 3.6+ MB

# %%
type(school_data_complete["Student ID"])
# Out:
# pandas.core.series.Series

# %%
school_data_complete.count()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# School ID        39170
# type             39170
# size             39170
# budget           39170
# dtype: int64

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
# School ID      15 non-null int64
# school_name    15 non-null object
# type           15 non-null object
# size           15 non-null int64
# budget         15 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 680.0+ bytes

# %%
school_data_complete.dtypes
# Out:
# Student ID        int64
# student_name     object
# gender           object
# grade            object
# school_name      object
# reading_score     int64
# math_score        int64
# School ID         int64
# type             object
# size              int64
# budget            int64
# dtype: object

# %%
#------------------FOR THE DISTRICT DATA FRAME ---------------------
# Calculate the totals for Schools, Students, and Budget
schoolTotal = school_data["School ID"].count()
#studentTotal = school_data_complete["student_name"].count().astype(float).map("{:,.2f}".format)   #??does not work
studentTotal = school_data_complete["student_name"].count()
budgetTotal = school_data["budget"].sum()

print("schoolTotal: " + str(schoolTotal))
print("studentTotal: " + str(studentTotal))
print("budgetTotal: " + str(budgetTotal))

# Calcuate the Average Math and Reading Scores
mathAverage = school_data_complete["math_score"].mean()
readingAverage = school_data_complete["reading_score"].mean()

print("mathAverage: " + str(mathAverage))
print("readingAverage: " + str(readingAverage))
type(budgetTotal)

# Calcuate the number of students who are passing match and reading.  Assume 70 is the passing score.
# Out:
# schoolTotal: 15
# studentTotal: 39170
# budgetTotal: 24649428
# mathAverage: 78.98537145774827
# readingAverage: 81.87784018381414
# numpy.int64

# %%
# Calcuate the number of students who are passing match and reading.  Assume 70 is the passing score.

passingReading = len(school_data_complete[(school_data_complete['reading_score']>=70)])
#print(passingReading)
percentPassingReading = (passingReading / studentTotal)*100 #instructions called for the column to indicate a %, so not convernting to %
#print(percentPassingReading)

passingMath = len(school_data_complete[(school_data_complete['math_score']>=70)])
#print(passingMath)
percentPassingMath = (passingMath / studentTotal)*100  #instructions called for the column to indicate a %, so not convernting to %
#print(percentPassingMath)
# Out:
# 29370
# 74.9808526933878
# 33610
# 85.80546336482001

# %%
#Calculate the overall passing score
#defined in instruction as: (avg. math score + avg. reading score)/2

overallPassScore = (mathAverage + readingAverage) / 2
print(overallPassScore)
# Out:
# 80.43160582078121

# %%
district_summary_df = pd.DataFrame({"Total Schools": [schoolTotal],
                           "Total Students": (studentTotal),
                           "Total Budget": [budgetTotal],
                            #"Total Budget2": [budgetTotal].astype(float).map("{:,0f}".format),  #??how do I define the format here?
                            "Average Reading Score": [readingAverage],
                           "Average Math Score": [mathAverage],
                           "% Passing Math": (percentPassingMath),
                            "% Passing Reading": (percentPassingReading),
                            "% Overall Passing Rate": (overallPassScore)
                          })

#format the values   ??  could I have included this in t data fram definition above?   I kept getting errors.
district_summary_df["Total Students"] = district_summary_df["Total Students"].astype(float).map("{:,.0f}".format)  
district_summary_df["Total Budget"] = district_summary_df["Total Budget"].astype(float).map("${:,.2f}".format)

#instructions indicate we should not round the average and passing scores; however, I think it looks better and it gave me practice so rounded to 4
#?? found some ways online to convert all entries in the table to x decimal places.  Can I more efficiently convert only these 5?
#EXTRA if time permits, come back and make this a working FOR loop
district_summary_df["Average Reading Score"] = district_summary_df["Average Reading Score"].astype(float).map("{:,.4f}".format) 
district_summary_df["Average Math Score"] = district_summary_df["Average Math Score"].astype(float).map("{:,.4f}".format) 
district_summary_df["% Passing Math"] = district_summary_df["% Passing Math"].astype(float).map("{:,.4f}".format) 
district_summary_df["% Passing Reading"] = district_summary_df["% Passing Reading"].astype(float).map("{:,.4f}".format) 
district_summary_df["% Overall Passing Rate"] = district_summary_df["% Overall Passing Rate"].astype(float).map("{:,.4f}".format) 
district_summary_df
# Out:
#    Total Schools Total Students    Total Budget Average Reading Score  \
# 0             15         39,170  $24,649,428.00               81.8778
#
#   Average Math Score % Passing Math % Passing Reading % Overall Passing Rate
# 0            78.9854        74.9809           85.8055                80.4316

# %%
district_summary_df
# Out:
#    Total Schools Total Students    Total Budget Average Reading Score  \
# 0             15         39,170  $24,649,428.00               81.8778
#
#   Average Math Score % Passing Math % Passing Reading % Overall Passing Rate
# 0            78.9854        74.9809           85.8055                80.4316

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#-----------------FOR THE SCHOOL DATA FRAME ----------------------------
"School Name" #groupby
"School Type" # groupby??
#"Total Students" #groupby SUM
#"Total School Budget" #Average of school budget
"Per Student Budget" # IN NEW DF?
#"Average Math Score" #average of average math score
#"Average Reading Score"   #average of average reading score
"% Passing Math"   #average of average passing math? from DISTRICT??
"% Passing Reading" #average of average passing math? from DISTRICT??
"Overall Passing Rate" ## IN NEW DF?

# %%
dfSchoolGroup = school_data_complete.groupby("school_name").agg({"student_name":'count',
                                                                 'budget':'mean',
                                                                 "math_score":'mean',
                                                                 "reading_score":'mean'
                                                                })

                                                            
#rename the column headers
dfSchoolGroup = dfSchoolGroup.rename(columns={"student_name": "Total Students", 
                                              "budget": "Total School Budget",
                                              "math_score": "Average Math Score",
                                              "reading_score": "Average Reading Score"
                                             })


dfSchoolGroup.head(20)
# Out:
#                        Total Students  Total School Budget  \
# school_name
# Bailey High School               4976              3124928
# Cabrera High School              1858              1081356
# Figueroa High School             2949              1884411
# Ford High School                 2739              1763916
# Griffin High School              1468               917500
# Hernandez High School            4635              3022020
# Holden High School                427               248087
# Huang High School                2917              1910635
# Johnson High School              4761              3094650
# Pena High School                  962               585858
# Rodriguez High School            3999              2547363
# Shelton High School              1761              1056600
# Thomas High School               1635              1043130
# Wilson High School               2283              1319574
# Wright High School               1800              1049400
#
# ...

# %%
#I now have part of the dataframe.   Need to add the other columns. 

dfSchoolGroupAll = dfSchoolGroup  #Add all the needed columns to this dataframe.   
dfSchoolGroupAll
# Out:
#                        Total Students  Total School Budget  \
# school_name
# Bailey High School               4976              3124928
# Cabrera High School              1858              1081356
# Figueroa High School             2949              1884411
# Ford High School                 2739              1763916
# Griffin High School              1468               917500
# Hernandez High School            4635              3022020
# Holden High School                427               248087
# Huang High School                2917              1910635
# Johnson High School              4761              3094650
# Pena High School                  962               585858
# Rodriguez High School            3999              2547363
# Shelton High School              1761              1056600
# Thomas High School               1635              1043130
# Wilson High School               2283              1319574
# Wright High School               1800              1049400
#
# ...

# %%
dfSchoolGroupAll["Per Student Budget"] = dfSchoolGroupAll["Total School Budget"] / dfSchoolGroupAll["Total Students"]

dfSchoolGroupAll["Overall Passing Rate"] =

# %%
# Combine the data into a single dataset
schoolWithScores = pd.merge(school_data, student_data, how="left", on=["school_name", "school_name"])
schoolWithScores.head(30)
# Out:
#     School ID        school_name      type  size   budget  Student ID  \
# 0           0  Huang High School  District  2917  1910635           0
# 1           0  Huang High School  District  2917  1910635           1
# 2           0  Huang High School  District  2917  1910635           2
# 3           0  Huang High School  District  2917  1910635           3
# 4           0  Huang High School  District  2917  1910635           4
# 5           0  Huang High School  District  2917  1910635           5
# 6           0  Huang High School  District  2917  1910635           6
# 7           0  Huang High School  District  2917  1910635           7
# 8           0  Huang High School  District  2917  1910635           8
# 9           0  Huang High School  District  2917  1910635           9
# 10          0  Huang High School  District  2917  1910635          10
# 11          0  Huang High School  District  2917  1910635          11
# ...

# %%
schoolWithScores.head()
# Out:
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#         student_name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %%
#delete the columns not needed
del schoolWithScores['School ID']
del schoolWithScores["Student ID"]
del schoolWithScores["student_name"]
del schoolWithScores["gender"]
del schoolWithScores["grade"]
schoolWithScores.head(20)
# Out:
#           school_name      type  size   budget  reading_score  math_score
# 0   Huang High School  District  2917  1910635             66          79
# 1   Huang High School  District  2917  1910635             94          61
# 2   Huang High School  District  2917  1910635             90          60
# 3   Huang High School  District  2917  1910635             67          58
# 4   Huang High School  District  2917  1910635             97          84
# 5   Huang High School  District  2917  1910635             94          94
# 6   Huang High School  District  2917  1910635             82          80
# 7   Huang High School  District  2917  1910635             96          69
# 8   Huang High School  District  2917  1910635             95          87
# 9   Huang High School  District  2917  1910635             96          84
# 10  Huang High School  District  2917  1910635             90          70
# 11  Huang High School  District  2917  1910635             78          77
# ...

# %%
#Add columns to indicate the number of students who are passing math and reading

schoolWithScores["Passing Reading?"] = np.where(schoolWithScores["reading_score"] >= 70, 1, 0)
schoolWithScores["Passing Math?"] = np.where(schoolWithScores["math_score"] >= 70, 1, 0)
schoolWithScores.head()
# Out:
#          school_name      type  size   budget  reading_score  math_score  \
# 0  Huang High School  District  2917  1910635             66          79
# 1  Huang High School  District  2917  1910635             94          61
# 2  Huang High School  District  2917  1910635             90          60
# 3  Huang High School  District  2917  1910635             67          58
# 4  Huang High School  District  2917  1910635             97          84
#
#    Passing Math?  Passing Reading?
# 0              1                 0
# 1              0                 1
# 2              0                 1
# 3              0                 0
# 4              1                 1

# %%
schoolWithScores.head()
# Out:
#          school_name      type  size   budget  reading_score  math_score  \
# 0  Huang High School  District  2917  1910635             66          79
# 1  Huang High School  District  2917  1910635             94          61
# 2  Huang High School  District  2917  1910635             90          60
# 3  Huang High School  District  2917  1910635             67          58
# 4  Huang High School  District  2917  1910635             97          84
#
#    Passing Math?  Passing Reading?
# 0              1                 0
# 1              0                 1
# 2              0                 1
# 3              0                 0
# 4              1                 1

# %%
#Sum the number of studets passing math and reading.   This will be needed later.
sumPassingMath = schoolWithScores["Passing Math?"].astype(float).sum()
sumPassingReading = schoolWithScores["Passing Reading?"].astype(float).sum()

#type(sumPassingMath), type(sumPassingReading)
# Out:
# (numpy.float64, numpy.float64)

# %%
#Add columns to indicate the average passing reading and math

dfSchoolGroup = schoolWithScores.groupby("school_name")

# %%
dfSchoolSumA = dfSchoolGroup.mean()
dfSchoolSumA.head()
# Out:
#                         size     budget  reading_score  math_score
# school_name
# Bailey High School    4976.0  3124928.0      81.033963   77.048432
# Cabrera High School   1858.0  1081356.0      83.975780   83.061895
# Figueroa High School  2949.0  1884411.0      81.158020   76.711767
# Ford High School      2739.0  1763916.0      80.746258   77.102592
# Griffin High School   1468.0   917500.0      83.816757   83.351499

# %%
#now that I have a list of the common averages, I can add the other values needed.

#?? how do I add the school type?
##dfSchoolSumA["Per Student Budget"] = dfSchoolSumA["budget"] / dfSchoolSumA["size"]
#dfSchoolSumA["%Percent Passing Math"] = schoolWithScores["Passing Math?"].astype(float).sum() / dfSchoolSumA["size"]  #??this is wrong
#dfSchoolSumA["%Percent Passing Reading"] = schoolWithScores["Passing Reading?"].astype(float).sum() / dfSchoolSumA["size"]  #??this is wrong

#district_summary_df["Total Students"] = district_summary_df["Total Students"].astype(float).map("{:,.0f}".format) 

dfSchoolSumA.head()
# Out:
#                         size     budget  reading_score  math_score  \
# school_name
# Bailey High School    4976.0  3124928.0      81.033963   77.048432
# Cabrera High School   1858.0  1081356.0      83.975780   83.061895
# Figueroa High School  2949.0  1884411.0      81.158020   76.711767
# Ford High School      2739.0  1763916.0      80.746258   77.102592
# Griffin High School   1468.0   917500.0      83.816757   83.351499
#
#                       Per Student Budget  %Percent Passing Math  \
# school_name
# Bailey High School                 628.0               5.902331
# Cabrera High School                582.0              15.807320
# Figueroa High School               639.0               9.959308
# Ford High School                   644.0              10.722892
# Griffin High School                625.0              20.006812
#
#                       %Percent Passing Reading
# school_name
# Bailey High School                    6.754421
# ...

# %%
#Save schoolWithScores to a new df where I will define how each column is aggregated into the new df
dfSchoolGroupAgg = schoolWithScores.groupby("school_name").agg({"size":'mean',
                                                                 "budget":'mean',
                                                                 "math_score":'mean',
                                                                 "reading_score":'mean',
                                                                 "Passing Math?" : 'sum',
                                                                 "Passing Reading?": 'sum'})

                                                            
#rename the column headers


dfSchoolGroupAgg.head(20)
# Out:
#                        size   budget  math_score  reading_score  \
# school_name
# Bailey High School     4976  3124928   77.048432      81.033963
# Cabrera High School    1858  1081356   83.061895      83.975780
# Figueroa High School   2949  1884411   76.711767      81.158020
# Ford High School       2739  1763916   77.102592      80.746258
# Griffin High School    1468   917500   83.351499      83.816757
# Hernandez High School  4635  3022020   77.289752      80.934412
# Holden High School      427   248087   83.803279      83.814988
# Huang High School      2917  1910635   76.629414      81.182722
# Johnson High School    4761  3094650   77.072464      80.966394
# Pena High School        962   585858   83.839917      84.044699
# Rodriguez High School  3999  2547363   76.842711      80.744686
# Shelton High School    1761  1056600   83.359455      83.725724
# Thomas High School     1635  1043130   83.418349      83.848930
# ...

# %%
#From the aggregated list, add the needed columns
dfSchoolGroupAggPlus = dfSchoolGroupAgg

dfSchoolGroupAggPlus.head(20)
# Out:
#                        size   budget  math_score  reading_score  \
# school_name
# Bailey High School     4976  3124928   77.048432      81.033963
# Cabrera High School    1858  1081356   83.061895      83.975780
# Figueroa High School   2949  1884411   76.711767      81.158020
# Ford High School       2739  1763916   77.102592      80.746258
# Griffin High School    1468   917500   83.351499      83.816757
# Hernandez High School  4635  3022020   77.289752      80.934412
# Holden High School      427   248087   83.803279      83.814988
# Huang High School      2917  1910635   76.629414      81.182722
# Johnson High School    4761  3094650   77.072464      80.966394
# Pena High School        962   585858   83.839917      84.044699
# Rodriguez High School  3999  2547363   76.842711      80.744686
# Shelton High School    1761  1056600   83.359455      83.725724
# Thomas High School     1635  1043130   83.418349      83.848930
# ...

# %%
#Add the missing columns

dfSchoolGroupAggPlus["Per Student Budget"] = dfSchoolGroupAggPlus["budget"] / dfSchoolGroupAggPlus["size"]
dfSchoolGroupAggPlus["%Percent Passing Reading"] = dfSchoolGroupAggPlus["Passing Reading?"] / dfSchoolGroupAggPlus["size"]
dfSchoolGroupAggPlus["%Percent Passing Math"] = dfSchoolGroupAggPlus["Passing Math?"] / dfSchoolGroupAggPlus["size"]
dfSchoolGroupAggPlus["Overall Pass Rate"] = (dfSchoolGroupAggPlus["%Percent Passing Reading"] + dfSchoolGroupAggPlus["%Percent Passing Math"]) / 2

dfSchoolGroupAggPlus.head(20)
# Out:
#                        size   budget  math_score  reading_score  \
# school_name
# Bailey High School     4976  3124928   77.048432      81.033963
# Cabrera High School    1858  1081356   83.061895      83.975780
# Figueroa High School   2949  1884411   76.711767      81.158020
# Ford High School       2739  1763916   77.102592      80.746258
# Griffin High School    1468   917500   83.351499      83.816757
# Hernandez High School  4635  3022020   77.289752      80.934412
# Holden High School      427   248087   83.803279      83.814988
# Huang High School      2917  1910635   76.629414      81.182722
# Johnson High School    4761  3094650   77.072464      80.966394
# Pena High School        962   585858   83.839917      84.044699
# Rodriguez High School  3999  2547363   76.842711      80.744686
# Shelton High School    1761  1056600   83.359455      83.725724
# Thomas High School     1635  1043130   83.418349      83.848930
# ...

# %%
dfSchoolGroupUnclean = dfSchoolGroupAggPlus
dfSchoolGroupUnclean.head(20)
# Out:
#                        size   budget  math_score  reading_score  \
# school_name
# Bailey High School     4976  3124928   77.048432      81.033963
# Cabrera High School    1858  1081356   83.061895      83.975780
# Figueroa High School   2949  1884411   76.711767      81.158020
# Ford High School       2739  1763916   77.102592      80.746258
# Griffin High School    1468   917500   83.351499      83.816757
# Hernandez High School  4635  3022020   77.289752      80.934412
# Holden High School      427   248087   83.803279      83.814988
# Huang High School      2917  1910635   76.629414      81.182722
# Johnson High School    4761  3094650   77.072464      80.966394
# Pena High School        962   585858   83.839917      84.044699
# Rodriguez High School  3999  2547363   76.842711      80.744686
# Shelton High School    1761  1056600   83.359455      83.725724
# Thomas High School     1635  1043130   83.418349      83.848930
# ...

# %%
dfSchoolDataToClean.columns
# Out:
# Index(['school_name', 'Total Students', 'Total Budget', 'Average Math Score',
#        'Average Reading Score', 'Per Student Budget',
#        '%Percent Passing Reading', '%Percent Passing Math',
#        'Overall Pass Rate', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
#Clean the data and order it as requested in the instructions

#delete the columns not needed
del dfSchoolGroupUnclean['Passing Math?']
del dfSchoolGroupUnclean["Passing Reading?"]

# %%
dfSchoolGroupUnclean.head(20)

# %%
#rename the column headers
dfSchoolGroupUnclean = dfSchoolGroupUnclean.rename(columns={"size": "Total Students", 
                                              "budget": "Total Budget",
                                              "math_score": "Average Math Score",
                                              "reading_score": "Average Reading Score"
                                             })

dfSchoolGroupUnclean.head(20)
# Out:
#                        Total Students  Total Budget  Average Math Score  \
# school_name
# Bailey High School               4976       3124928           77.048432
# Cabrera High School              1858       1081356           83.061895
# Figueroa High School             2949       1884411           76.711767
# Ford High School                 2739       1763916           77.102592
# Griffin High School              1468        917500           83.351499
# Hernandez High School            4635       3022020           77.289752
# Holden High School                427        248087           83.803279
# Huang High School                2917       1910635           76.629414
# Johnson High School              4761       3094650           77.072464
# Pena High School                  962        585858           83.839917
# Rodriguez High School            3999       2547363           76.842711
# Shelton High School              1761       1056600           83.359455
# ...

# %%
#The only missing column is the school type.  Create a merge to get this data from the original school_date

dfSchoolDataType = pd.merge(dfSchoolGroupUnclean, school_data, how="left", on=["school_name", "school_name"])

# %%
dfSchoolDataType.head()
# Out:
#             school_name  Total Students  Total Budget  Average Math Score  \
# 0    Bailey High School            4976       3124928           77.048432
# 1   Cabrera High School            1858       1081356           83.061895
# 2  Figueroa High School            2949       1884411           76.711767
# 3      Ford High School            2739       1763916           77.102592
# 4   Griffin High School            1468        917500           83.351499
#
#    Average Reading Score  Per Student Budget  %Percent Passing Reading  \
# 0              81.033963               628.0                  0.819333
# 1              83.975780               582.0                  0.970398
# 2              81.158020               639.0                  0.807392
# 3              80.746258               644.0                  0.792990
# 4              83.816757               625.0                  0.971390
#
#    %Percent Passing Math  Overall Pass Rate  School ID      type  size  \
# ...

# %%
dfSchoolDataType.columns
# Out:
# Index(['school_name', 'Total Students', 'Total Budget', 'Average Math Score',
#        'Average Reading Score', 'Per Student Budget',
#        '%Percent Passing Reading', '%Percent Passing Math',
#        'Overall Pass Rate', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
#now keep only those columns needed and set them in the order required by the new dataframe

dfSchoolDataOrdered = dfSchoolDataType[["school_name", "type", "Total Students", "Total Budget", "Per Student Budget", "Average Math Score",
                                       "Average Reading Score", "%Percent Passing Math", "%Percent Passing Reading", "Overall Pass Rate"]]

# %%
dfSchoolDataOrdered.head(20)
# Out:
#               school_name      type  Total Students  Total Budget  \
# 0      Bailey High School  District            4976       3124928
# 1     Cabrera High School   Charter            1858       1081356
# 2    Figueroa High School  District            2949       1884411
# 3        Ford High School  District            2739       1763916
# 4     Griffin High School   Charter            1468        917500
# 5   Hernandez High School  District            4635       3022020
# 6      Holden High School   Charter             427        248087
# 7       Huang High School  District            2917       1910635
# 8     Johnson High School  District            4761       3094650
# 9        Pena High School   Charter             962        585858
# 10  Rodriguez High School  District            3999       2547363
# 11    Shelton High School   Charter            1761       1056600
# 12     Thomas High School   Charter            1635       1043130
# ...

# %%
dfSchoolDataFinal = dfSchoolDataOrdered
dfSchoolDataFinal.head(20)
# Out:
#               school_name      type  Total Students  Total Budget  \
# 0      Bailey High School  District            4976       3124928
# 1     Cabrera High School   Charter            1858       1081356
# 2    Figueroa High School  District            2949       1884411
# 3        Ford High School  District            2739       1763916
# 4     Griffin High School   Charter            1468        917500
# 5   Hernandez High School  District            4635       3022020
# 6      Holden High School   Charter             427        248087
# 7       Huang High School  District            2917       1910635
# 8     Johnson High School  District            4761       3094650
# 9        Pena High School   Charter             962        585858
# 10  Rodriguez High School  District            3999       2547363
# 11    Shelton High School   Charter            1761       1056600
# 12     Thomas High School   Charter            1635       1043130
# ...

# %%
#rename the column headers from the merge
dfSchoolDataFinal = dfSchoolDataFinal.rename(columns={"school_name": "School Name", 
                                              "type": "Type"
                                             })
dfSchoolDataFinal.head(20)
# Out:
#               School Name      Type  Total Students  Total Budget  \
# 0      Bailey High School  District            4976       3124928
# 1     Cabrera High School   Charter            1858       1081356
# 2    Figueroa High School  District            2949       1884411
# 3        Ford High School  District            2739       1763916
# 4     Griffin High School   Charter            1468        917500
# 5   Hernandez High School  District            4635       3022020
# 6      Holden High School   Charter             427        248087
# 7       Huang High School  District            2917       1910635
# 8     Johnson High School  District            4761       3094650
# 9        Pena High School   Charter             962        585858
# 10  Rodriguez High School  District            3999       2547363
# 11    Shelton High School   Charter            1761       1056600
# 12     Thomas High School   Charter            1635       1043130
# ...

# %%
dfSchoolDataFormattedFinal = dfSchoolDataFinal   #keep a copy of the unformatted values...just in case I need to look back at these or use them in an upcoming example.

dfSchoolDataFormattedFinal.head(20)
# Out:
#               School Name      Type  Total Students  Total Budget  \
# 0      Bailey High School  District            4976       3124928
# 1     Cabrera High School   Charter            1858       1081356
# 2    Figueroa High School  District            2949       1884411
# 3        Ford High School  District            2739       1763916
# 4     Griffin High School   Charter            1468        917500
# 5   Hernandez High School  District            4635       3022020
# 6      Holden High School   Charter             427        248087
# 7       Huang High School  District            2917       1910635
# 8     Johnson High School  District            4761       3094650
# 9        Pena High School   Charter             962        585858
# 10  Rodriguez High School  District            3999       2547363
# 11    Shelton High School   Charter            1761       1056600
# 12     Thomas High School   Charter            1635       1043130
# ...

# %%
#Add user friendly formatting
dfSchoolDataFormattedFinal["Total Students"] = dfSchoolDataFormattedFinal["Total Students"].astype(float).map("{:,.0f}".format)
dfSchoolDataFormattedFinal["Total Budget"] = dfSchoolDataFormattedFinal["Total Budget"].astype(float).map("${:,.2f}".format)
dfSchoolDataFormattedFinal["Per Student Budget"] = dfSchoolDataFormattedFinal["Per Student Budget"].astype(float).map("${:,.2f}".format)
dfSchoolDataFormattedFinal["Average Math Score"] = dfSchoolDataFormattedFinal["Average Math Score"].astype(float).map("{:,.4f}".format)
dfSchoolDataFormattedFinal["Average Reading Score"] = dfSchoolDataFormattedFinal["Average Reading Score"].astype(float).map("{:,.4f}".format)

dfSchoolDataFormattedFinal.head(20)
# Out:
#               School Name      Type Total Students   Total Budget  \
# 0      Bailey High School  District          4,976  $3,124,928.00
# 1     Cabrera High School   Charter          1,858  $1,081,356.00
# 2    Figueroa High School  District          2,949  $1,884,411.00
# 3        Ford High School  District          2,739  $1,763,916.00
# 4     Griffin High School   Charter          1,468    $917,500.00
# 5   Hernandez High School  District          4,635  $3,022,020.00
# 6      Holden High School   Charter            427    $248,087.00
# 7       Huang High School  District          2,917  $1,910,635.00
# 8     Johnson High School  District          4,761  $3,094,650.00
# 9        Pena High School   Charter            962    $585,858.00
# 10  Rodriguez High School  District          3,999  $2,547,363.00
# 11    Shelton High School   Charter          1,761  $1,056,600.00
# 12     Thomas High School   Charter          1,635  $1,043,130.00
# ...

# %%
dfSchoolDataFormattedFinal["%Percent Passing Math"] = dfSchoolDataFormattedFinal["%Percent Passing Math"].astype(float).map("{:,.3%}".format)

# %%
dfSchoolDataFormattedFinal["%Percent Passing Reading"] = dfSchoolDataFormattedFinal["%Percent Passing Reading"].astype(float).map("{:,.3%}".format)
dfSchoolDataFormattedFinal["Overall Pass Rate"] = dfSchoolDataFormattedFinal["Overall Pass Rate"].astype(float).map("{:,.3%}".format)

dfSchoolDataFormattedFinal.head(20)
# Out:
#               School Name      Type Total Students   Total Budget  \
# 0      Bailey High School  District          4,976  $3,124,928.00
# 1     Cabrera High School   Charter          1,858  $1,081,356.00
# 2    Figueroa High School  District          2,949  $1,884,411.00
# 3        Ford High School  District          2,739  $1,763,916.00
# 4     Griffin High School   Charter          1,468    $917,500.00
# 5   Hernandez High School  District          4,635  $3,022,020.00
# 6      Holden High School   Charter            427    $248,087.00
# 7       Huang High School  District          2,917  $1,910,635.00
# 8     Johnson High School  District          4,761  $3,094,650.00
# 9        Pena High School   Charter            962    $585,858.00
# 10  Rodriguez High School  District          3,999  $2,547,363.00
# 11    Shelton High School   Charter          1,761  $1,056,600.00
# 12     Thomas High School   Charter          1,635  $1,043,130.00
# ...

# %% [markdown]
# # BEGIN Problem 3 - Top Performing Schools (By Passing Rate)

# %%
dfSchoolDataTopPass = dfSchoolDataFinal

# %%
dfSchoolDataFinal.head(20)
# Out:
#               School Name      Type Total Students   Total Budget  \
# 0      Bailey High School  District          4,976  $3,124,928.00
# 1     Cabrera High School   Charter          1,858  $1,081,356.00
# 2    Figueroa High School  District          2,949  $1,884,411.00
# 3        Ford High School  District          2,739  $1,763,916.00
# 4     Griffin High School   Charter          1,468    $917,500.00
# 5   Hernandez High School  District          4,635  $3,022,020.00
# 6      Holden High School   Charter            427    $248,087.00
# 7       Huang High School  District          2,917  $1,910,635.00
# 8     Johnson High School  District          4,761  $3,094,650.00
# 9        Pena High School   Charter            962    $585,858.00
# 10  Rodriguez High School  District          3,999  $2,547,363.00
# 11    Shelton High School   Charter          1,761  $1,056,600.00
# 12     Thomas High School   Charter          1,635  $1,043,130.00
# ...

# %%
#dfSchoolDataTopPass.sort("Overall Pass Rate", ascending=False) #did not work

#dfSchoolDataTopPass.sort_values(by='Total Students', ascending = True)  #??does not work  and appears to not chagne the data.   still by School Name

dfSchoolDataTopPass.head(20)
# Out:
#               School Name      Type Total Students   Total Budget  \
# 0      Bailey High School  District          4,976  $3,124,928.00
# 1     Cabrera High School   Charter          1,858  $1,081,356.00
# 2    Figueroa High School  District          2,949  $1,884,411.00
# 3        Ford High School  District          2,739  $1,763,916.00
# 4     Griffin High School   Charter          1,468    $917,500.00
# 5   Hernandez High School  District          4,635  $3,022,020.00
# 6      Holden High School   Charter            427    $248,087.00
# 7       Huang High School  District          2,917  $1,910,635.00
# 8     Johnson High School  District          4,761  $3,094,650.00
# 9        Pena High School   Charter            962    $585,858.00
# 10  Rodriguez High School  District          3,999  $2,547,363.00
# 11    Shelton High School   Charter          1,761  $1,056,600.00
# 12     Thomas High School   Charter          1,635  $1,043,130.00
# ...

# %%
type(dfSchoolDataTopPass["Total Students"])  #I am trying to find tyep for overall pass rate, but switched to trying just any field to show a value.
# Out:
# pandas.core.series.Series

# %%
dfSchoolDataTopPass.info()  #??why does this not return the data types?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 10 columns):
# School Name                 15 non-null object
# Type                        15 non-null object
# Total Students              15 non-null object
# Total Budget                15 non-null object
# Per Student Budget          15 non-null object
# Average Math Score          15 non-null object
# Average Reading Score       15 non-null object
# %Percent Passing Math       15 non-null object
# %Percent Passing Reading    15 non-null object
# Overall Pass Rate           15 non-null object
# dtypes: object(10)
# memory usage: 1.3+ KB
